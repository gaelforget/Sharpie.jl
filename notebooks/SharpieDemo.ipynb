# %% [markdown]
# **Tip:** just hit run in the menu bar at the top

# %%
using Sharpie
Sharpie.BeforeAndAfter()
# Out:
# 480×1280 Array{RGB4{N0f8},2} with eltype ColorTypes.RGB4{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB4{N0f8}(0.878,0.843,0.816)  …  RGB4{N0f8}(0.894,0.882,0.863)
#  RGB4{N0f8}(0.882,0.847,0.82)      RGB4{N0f8}(0.894,0.882,0.863)
#  RGB4{N0f8}(0.886,0.851,0.824)     RGB4{N0f8}(0.894,0.882,0.863)
#  RGB4{N0f8}(0.886,0.851,0.824)     RGB4{N0f8}(0.894,0.882,0.863)
#  RGB4{N0f8}(0.882,0.847,0.82)      RGB4{N0f8}(0.894,0.882,0.863)
#  RGB4{N0f8}(0.882,0.847,0.82)   …  RGB4{N0f8}(0.898,0.886,0.867)
#  RGB4{N0f8}(0.882,0.847,0.82)      RGB4{N0f8}(0.898,0.882,0.871)
#  RGB4{N0f8}(0.882,0.847,0.82)      RGB4{N0f8}(0.898,0.882,0.871)
#  RGB4{N0f8}(0.89,0.863,0.831)      RGB4{N0f8}(0.894,0.878,0.867)
#  RGB4{N0f8}(0.886,0.859,0.827)     RGB4{N0f8}(0.894,0.878,0.867)
#  RGB4{N0f8}(0.882,0.855,0.824)  …  RGB4{N0f8}(0.894,0.878,0.867)
#  RGB4{N0f8}(0.878,0.851,0.82)      RGB4{N0f8}(0.894,0.878,0.867)
#  RGB4{N0f8}(0.871,0.855,0.82)      RGB4{N0f8}(0.89,0.878,0.859)
# ...
